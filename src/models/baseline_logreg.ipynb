# %%
import sys
sys.path.append("..")

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

from preprocessing import build_preprocessor
from baseline_logreg import build_baseline_logreg
from result import evaluate_baseline_results

# %%
df = pd.read_csv("../output/features.csv")

X = df.drop(columns=["pathology", "assessment", "patient_id", "id"])
y = df["pathology"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("../output/features.csv")
#       3 X = df.drop(columns=["pathology", "assessment", "patient_id", "id"])
#       4 y = df["pathology"]
#
# File ~\Desktop\mammography-delta\.venv\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\Desktop\mammography-delta\.venv\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\Desktop\mammography-delta\.venv\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\Desktop\mammography-delta\.venv\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\Desktop\mammography-delta\.venv\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output/features.csv'

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

preprocessor = build_preprocessor(X_train)
model = build_baseline_logreg(preprocessor)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)[:, 1]

accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_proba)

print(f"Accuracy: {accuracy:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"ROC-AUC: {roc_auc:.4f}")
# Out:
# Accuracy: 0.5706
# F1-score: 0.4762
# ROC-AUC: 0.6127

# %%
y_random = np.random.randint(0, 2, size=len(y_test))
y_random_proba = np.random.rand(len(y_test))

random_accuracy = accuracy_score(y_test, y_random)
random_f1 = f1_score(y_test, y_random)
random_roc_auc = roc_auc_score(y_test, y_random_proba)

print(f"Accuracy: {random_accuracy:.4f}")
print(f"F1-score: {random_f1:.4f}")
print(f"ROC-AUC: {random_roc_auc:.4f}")
# Out:
# Accuracy: 0.5405
# F1-score: 0.5350
# ROC-AUC: 0.4608

# %%
results = pd.DataFrame({
    "Model": ["Random", "Logistic Regression (Baseline)"],
    "Accuracy": [random_accuracy, accuracy],
    "F1-score": [random_f1, f1],
    "ROC-AUC": [random_roc_auc, roc_auc]
})

results
# Out:
#                             Model  Accuracy  F1-score   ROC-AUC
# 0                          Random  0.540541  0.534954  0.460784
# 1  Logistic Regression (Baseline)  0.570571  0.476190  0.612745

# %%
evaluate_baseline_results(results)
# Out:
# Baseline does NOT outperform random baseline.
